# %% [markdown]
# <a href="https://colab.research.google.com/github/bpawluczuk/BazaPrzedmiotow/blob/master/py_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set()

w = np.arange(-10, 14, 0.1)
data = np.random.randn(1,10)
df = pd.DataFrame(data)

point = -5

loss = w**2 - 4*w
plt.plot(w, loss)
plt.plot(point, point**2 - 4*point, 'ro')

def gradient_descent(df=lambda w: 2*w - 4, learning_rate = 0.01, w_0 = -5, max_iter=10000, precision=0.000001):

  iters = 0
  previous_step_size = 1
